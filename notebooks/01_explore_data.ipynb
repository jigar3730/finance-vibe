# %%
# 1. Calculate a 5-day moving average
df['5d_MA'] = df['Close'].rolling(window=5).mean()

# 2. Plot both the original Close price and the Moving Average
plt.figure(figsize=(10, 5))
plt.plot(df['Close'], label='AAPL Close', alpha=0.5) # Alpha makes it slightly transparent
plt.plot(df['5d_MA'], label='5-Day Moving Average', color='orange', linewidth=2)

plt.title('Apple (AAPL) Trend Analysis')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1. Load the data from our robust structure
# We use ../ to go 'up' out of the notebooks folder and into data
df = pd.read_csv("../data/raw/AAPL_history.csv", index_col='Date', parse_dates=True)

# 2. Basic Plotting
plt.figure(figsize=(10, 5))
plt.plot(df['Close'], label='AAPL Closing Price')
plt.title('Apple Stock Price - Last 1 Month')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend()
plt.grid(True)
plt.show()
